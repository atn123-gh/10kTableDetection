# %%
# Reference 
# https://github.com/karndeepsingh/layout_parser_implementation
# https://www.youtube.com/watch?v=puOKTFXRyr4&t=961s(Customized Layout Detection for Scientific PDFs with LayoutParser and Label-Studio)


# After fine tuning

# %%
import layoutparser as lp
import cv2

# before custom training
# model = lp.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
#                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.7],
#                                  label_map={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"})

model = lp.Detectron2LayoutModel(
    config_path = "outputs/config.yaml",
    model_path = "training/training-outputs/model_final.pth",
    extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST",0.8]
)

# %%
image = cv2.imread("data/images/4/0d18aeed-amg-20211231_46.png")
layout = model.detect(image)
lp.draw_box(image, layout,)
# Out:
# <PIL.Image.Image image mode=RGB size=1653x2339 at 0x7F57FDC24650>

# %%
image = cv2.imread("data/images/4/3bee4449-eqix-20211231_122.png")
layout = model.detect(image)
lp.draw_box(image, layout,)
# Out:
# <PIL.Image.Image image mode=RGB size=1653x2339 at 0x7F57FDAF2B50>

# %%
image = cv2.imread("data/images/4/4be8a892-eqix-20211231_66.png")
layout = model.detect(image)
lp.draw_box(image, layout,)
# Out:
# <PIL.Image.Image image mode=RGB size=1653x2339 at 0x7F57FF848F50>

# %%
image = cv2.imread("data/images/4/9abffd3d-cxw-10k_20211231_151.png")
layout = model.detect(image)
lp.draw_box(image, layout,)
# Out:
# <PIL.Image.Image image mode=RGB size=1653x2339 at 0x7F57F3DE93D0>
